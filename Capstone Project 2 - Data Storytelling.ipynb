# %% [markdown]
# # Data Storytelling for NBA Boxscore Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
games = pd.read_csv('C:/Users/michael.thabane/Documents/Springboard/Capstone2/nba-games/games.csv')
games_details = pd.read_csv('C:/Users/michael.thabane/Documents/Springboard/Capstone2/nba-games/games_details.csv')
players = pd.read_csv('C:/Users/michael.thabane/Documents/Springboard/Capstone2/nba-games/players.csv')
standings = pd.read_csv('C:/Users/michael.thabane/Documents/Springboard/Capstone2/nba-games/ranking.csv')

# %% [markdown]
# ### Data Wrangling Steps Taken in First Notebook

# %%
# convert date string to datetime variable
from datetime import datetime
games['GAME_DATE_EST'] = [datetime.strptime(x,'%Y-%m-%d') for x in games['GAME_DATE_EST']]
standings['STANDINGSDATE'] = [datetime.strptime(x,'%Y-%m-%d') for x in standings['STANDINGSDATE']]

# %%
final_boxscore = games_details.merge(games, left_on='GAME_ID', right_on="GAME_ID", how='inner')

# %%
final_boxscore = final_boxscore[['SEASON','GAME_ID','GAME_DATE_EST','TEAM_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','TEAM_ABBREVIATION',
                                'TEAM_CITY','PLAYER_ID','PLAYER_NAME','START_POSITION','MIN', 'PTS','FGM','FGA','FG_PCT',
                                'FG3M', 'FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO',
                                'PF', 'PLUS_MINUS','PTS_home','PTS_away', 'AST_home','AST_away','REB_home','REB_away',
                                'FG_PCT_home','FG_PCT_away','FT_PCT_home','FT_PCT_away','FG3_PCT_home','FG3_PCT_away']]

# %%
final_boxscore['GAME_LOC'] = np.where(final_boxscore['TEAM_ID'] == final_boxscore['HOME_TEAM_ID'], 'HOME','AWAY')

# %%
final_boxscore['TOT_PTS'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['PTS_home'] , final_boxscore['PTS_away'])
final_boxscore['TOT_AST'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['AST_home'] , final_boxscore['AST_away'])
final_boxscore['TOT_REB'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['REB_home'] , final_boxscore['REB_away'])
final_boxscore['TOT_FG_PCT'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['FG_PCT_home'] , final_boxscore['FG_PCT_away'])
final_boxscore['TOT_FT_PCT'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['FT_PCT_home'] , final_boxscore['FT_PCT_away'])
final_boxscore['TOT_FG3_PCT'] = np.where(final_boxscore['GAME_LOC'] == 'HOME', final_boxscore['FG3_PCT_home'] , final_boxscore['FG3_PCT_away'])

# %%
final_boxscore = final_boxscore[['SEASON','GAME_ID','GAME_DATE_EST','TEAM_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','TEAM_ABBREVIATION',
                                'TEAM_CITY','GAME_LOC','PLAYER_ID','PLAYER_NAME','START_POSITION','MIN', 'PTS','FGM','FGA',
                                'FG_PCT','FG3M', 'FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB', 'DREB', 'REB', 'AST', 'STL', 
                                'BLK','TO', 'PF', 'PLUS_MINUS','TOT_PTS','TOT_AST','TOT_REB','TOT_FG_PCT','TOT_FT_PCT',
                                'TOT_FG3_PCT']]

# %%
final_boxscore.set_index('GAME_DATE_EST')
# Out:
#                SEASON   GAME_ID     TEAM_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 2020-03-01        20.0     61.0       0.402       0.762        0.226
# ...                ...      ...         ...         ...          ...
# 2012-10-06        25.0     34.0       0.532       0.615        0.471
# 2012-10-06        25.0     34.0       0.532       0.615        0.471
# 2012-10-06        25.0     34.0       0.532       0.615        0.471
# 2012-10-06        25.0     34.0       0.532       0.615        0.471
# 2012-10-06        25.0     34.0       0.532       0.615        0.471
#
# [576782 rows x 37 columns]

# %% [markdown]
# #### Let us only get data from players who have started a game in the 2019/2020 season

# %%
Start_guard = final_boxscore.loc[final_boxscore['START_POSITION'] == 'G']
Start_forward = final_boxscore.loc[final_boxscore['START_POSITION'] == 'F']
Start_Center = final_boxscore.loc[final_boxscore['START_POSITION'] == 'C']
Starters = Start_guard.append(Start_forward.append(Start_Center))
Starters = Starters.reset_index(drop= True)

# %%
started2019 = Starters.loc[Starters['SEASON'] == 2019]
SPI = started2019['PLAYER_ID'].unique()
Started_2019 = pd.DataFrame(columns = final_boxscore.columns)

# %%
for playerID in SPI:
    Data_Append = final_boxscore[final_boxscore['PLAYER_ID'] == playerID]
    Started_2019 = Started_2019.append(Data_Append)

# %%
Started_2019
# Out:
#        SEASON   GAME_ID GAME_DATE_EST     TEAM_ID HOME_TEAM_ID  \
# 3        2019  21900895    2020-03-01  1610612749   1610612766
# 510      2019  21900882    2020-02-28  1610612749   1610612749
# 975      2019  21900858    2020-02-25  1610612749   1610612761
# 1175     2019  21900851    2020-02-24  1610612749   1610612764
# 1634     2019  21900840    2020-02-22  1610612749   1610612749
# ...       ...       ...           ...         ...          ...
# 574042   2012  21200004    2012-10-31  1610612761   1610612761
# 574831   2012  11200089    2012-10-22  1610612761   1610612761
# 575551   2012  11200060    2012-10-17  1610612761   1610612761
# 576111   2012  11200030    2012-10-12  1610612761   1610612761
# 576392   2012  11200023    2012-10-10  1610612761   1610612765
#
#        VISITOR_TEAM_ID TEAM_ABBREVIATION  TEAM_CITY GAME_LOC PLAYER_ID  ...  \
# 3           1610612749               MIL  Milwaukee     AWAY   1628978  ...
# 510         1610612760               MIL  Milwaukee     HOME   1628978  ...
# 975         1610612749               MIL  Milwaukee     AWAY   1628978  ...
# 1175        1610612749               MIL  Milwaukee     AWAY   1628978  ...
# 1634        1610612755               MIL  Milwaukee     HOME   1628978  ...
# ...                ...               ...        ...      ...       ...  ...
# 574042      1610612754               TOR    Toronto     HOME    202334  ...
# 574831      1610612749               TOR    Toronto     HOME    202334  ...
# 575551      1610612764               TOR    Toronto     HOME    202334  ...
# 576111      1610612765               TOR    Toronto     HOME    202334  ...
# 576392      1610612761               TOR    Toronto     AWAY    202334  ...
#
#         BLK   TO   PF  PLUS_MINUS  TOT_PTS  TOT_AST  TOT_REB  TOT_FG_PCT  \
# 3       1.0  2.0  0.0        14.0     93.0     20.0     61.0       0.402
# 510     0.0  2.0  2.0         1.0    133.0     34.0     66.0       0.500
# 975     0.0  0.0  2.0         2.0    108.0     23.0     53.0       0.381
# 1175    0.0  3.0  2.0        -5.0    137.0     26.0     45.0       0.570
# 1634    0.0  1.0  1.0         8.0    119.0     35.0     57.0       0.527
# ...     ...  ...  ...         ...      ...      ...      ...         ...
# 574042  2.0  2.0  1.0         1.0     88.0     18.0     42.0       0.363
# 574831  0.0  0.0  0.0         NaN    104.0     24.0     49.0       0.455
# 575551  1.0  2.0  3.0         NaN    104.0     23.0     40.0       0.500
# 576111  1.0  2.0  2.0         NaN     82.0     17.0     41.0       0.394
# 576392  0.0  2.0  1.0         NaN     99.0     20.0     32.0       0.473
#
#         TOT_FT_PCT  TOT_FG3_PCT
# 3            0.762        0.226
# 510          0.857        0.467
# 975          0.833        0.333
# 1175         0.815        0.459
# 1634         0.692        0.341
# ...            ...          ...
# 574042       0.842        0.353
# 574831       0.714        0.450
# 575551       0.741        0.267
# 576111       0.955        0.294
# 576392       0.643        0.423
#
# [312982 rows x 38 columns]

# %%
desc = Started_2019['PTS'].groupby([Started_2019['SEASON'], Started_2019['START_POSITION']]).describe()

# %%
final = pd.DataFrame(desc)

# %%
final.iloc[0,0]
# Out:
# 188.0

# %%
SEASON = pd.DataFrame(final.droplevel('START_POSITION').index)
SP = pd.DataFrame(final.droplevel('SEASON').index)

# %%
final = final.reset_index(drop= True)
final_desc = pd.concat([SEASON, SP, final], axis=1, sort=False)

# %%
final_desc
# Out:
#     SEASON START_POSITION    count       mean        std  min    25%   50%  \
# 0     2003              F    188.0  20.085106   8.034231  2.0  14.00  20.0
# 1     2003              G    158.0  20.936709   8.153530  4.0  15.00  20.0
# 2     2004              C      6.0   5.666667   2.250926  3.0   3.75   6.0
# 3     2004              F    504.0  18.920635   9.249451  2.0  11.00  19.0
# 4     2004              G     18.0  24.444444  15.447148  6.0  14.00  23.0
# 5     2005              C     82.0   4.951220   3.310673  0.0   3.00   4.0
# 6     2005              F    566.0  23.226148  10.502680  0.0  16.00  23.0
# 7     2005              G    158.0  15.974684   6.354646  1.0  11.00  16.0
# 8     2006              C    344.0  13.505814   7.377767  0.0   8.00  13.0
# 9     2006              F    520.0  22.300000  10.036657  0.0  14.75  23.0
# 10    2006              G    270.0  14.444444   7.452119  0.0   8.25  15.0
# 11    2007              C    534.0  14.205993   7.265449  2.0   9.00  13.0
# 12    2007              F   1018.0  19.518664   9.440709  0.0  12.00  19.0
# 13    2007              G    522.0  14.379310   8.572475  0.0   8.00  14.0
# 14    2008              C    840.0  13.564286   7.484790  0.0   8.00  13.0
# 15    2008              F   1516.0  17.118734   9.511037  0.0  10.00  16.0
# 16    2008              G   1172.0  15.081911   8.029841  0.0   9.00  14.0
# 17    2009              C    864.0  14.997685   7.173241  0.0  10.00  14.0
# 18    2009              F   1708.0  16.778689   9.277671  0.0  10.00  15.0
# 19    2009              G   1916.0  14.677453   7.398633  0.0   9.00  14.0
# 20    2010              C   1280.0  13.393750   8.069748  0.0   7.00  12.0
# 21    2010              F   2184.0  17.076923   8.913980  0.0  11.00  16.0
# 22    2010              G   2202.0  16.454133   8.237663  0.0  10.00  16.0
# 23    2011              C    876.0  11.860731   7.618999  0.0   7.00  11.0
